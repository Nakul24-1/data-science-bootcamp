# %% [markdown]
# # **Task 03**: Python Libraries (*Pokemon Dataset*)

# %% [markdown]
# As discussed during the session, we decided to use the Pokemon dataset to understand the basics of Pandas and Data Visualization. In this task, we will be doing pretty much the same.
#
# **At any point, feel free to refer the notebook available** [here](https://github.com/NYU-DataScienceBootCamp/Week-3-Libraries/blob/main/Week_03_Python_Libraries.ipynb)

# %% [markdown]
# ## Importing utils
#
# Import the necessary 'libraries' (/modules) that will be needed to solve the task and perform necessary operations.
#
# *Hint:* You will need to import numpy, pandas, matplotlib, and seaborn.
#
# **NOTE:** Make sure you use the naming convention which makes it easier for anybody to read the code and comment any necessary messages.

# %%
# import library as lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# ## Understanding Numpy
#
# This section is for testing your basic knowledge of `numpy`

# %%
# TODO 1: Create a simple array with 5 elements and print their datatype

array1 = np.array([1,4,5,2,7])
print(array1)
print(array1.dtype)
# Out:
# [1 4 5 2 7]
# int32

# %%
# TODO 2: Generate a matrix of size 4 x 4 which has random values between 0 and 1
np.random.rand(4,4)
# Out:
# array([[0.89361124, 0.01559619, 0.69243555, 0.63686337],
#        [0.53716853, 0.55246286, 0.8835154 , 0.90242308],
#        [0.28685005, 0.32888852, 0.40372479, 0.77771865],
#        [0.30007849, 0.26817291, 0.81182974, 0.72469801]])

# %%
# TODO 3: Generate a matrix of size 4 x 4, but by entering the order as a list
np.array([[1,2,3,1],[1,2,3,1],[2,2,3,2],[1,1,1,1]])
# Out:
# array([[1, 2, 3, 1],
#        [1, 2, 3, 1],
#        [2, 2, 3, 2],
#        [1, 1, 1, 1]])

# %%
# TODO 4: Create a 3-D Array

np.random.rand(3,3,3)
# Out:
# array([[[0.62106671, 0.77854156, 0.97088361],
#         [0.64230171, 0.477255  , 0.76508589],
#         [0.70961774, 0.13159326, 0.41753267]],
#
#        [[0.34753853, 0.28831578, 0.27677803],
#         [0.25374239, 0.13995191, 0.46710245],
#         [0.67204098, 0.67350482, 0.1949975 ]],
#
#        [[0.79112368, 0.41756099, 0.44732299],
#         [0.44976973, 0.84535128, 0.18735819],
#         [0.76680874, 0.47454318, 0.54733501]]])

# %% [markdown]
# ## Pokemon Dataset
#
# Download the `pokemon.csv` from the repository in the `task-week3` folder

# %% [markdown]
# ### Introduction

# %%
from google.colab import files
files.upload()

# %%
# TODO 5: Read the `Pokemon.csv` file and name is display the first 5 rows
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# TODO 6: Display the information
df.info
# Out:
# <bound method DataFrame.info of        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 12 columns]>

# %%
# corr() computes the correlation of columns excluding Null values

df.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# Sp. Atk     0.473018    0.036437   0.448907
# Sp. Def     0.259133    0.028486   0.363937
# Speed       1.000000   -0.023121   0.326715
# Generation -0.023121    1.000000   0.079794
# Legendary   0.326715    0.079794   1.000000

# %%
# Extra information: Correlation Map

f, ax = plt.subplots(figsize = (18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt='.1f', ax=ax)

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# **TODO 7:** Line Plotting </br>
# Have a line plot plotting speed and defense along the same axis and the same graph </br>
# The expected output is as shown:
#
# ![download.png](data:image/png;base64,...)
#
# Make sure that you also have a legend and the axes are labeled.

# %%
# Run TODO 7 here
plt.plot(df.Speed,linestyle='dotted',color='green',alpha=0.5)
plt.plot(df.Defense,linestyle='dotted',color='red',alpha=0.5)
plt.legend(['Speed','Defense'])
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %% [markdown]
# **TODO 8:** Scatter Plot </br>
# Plot a scatterplot with `x = attack` and `y = defense` </br>
# The expected output is as shown:
#
# ![download (1).png](data:image/png;base64,...)

# %%
# Run TODO 8 here
plt.scatter(x=df.Attack,y=df.Defense,alpha=0.5,color='b')
plt.title('Attack Defense Scatter Plot')
plt.xlabel('Attack')
plt.ylabel('Defense')
# Out:
# Text(0, 0.5, 'Defense')

# %% [markdown]
# ### Pandas

# %%
# TODO 9: Display the Pokemon who have Defense greater than 200

defense=df[['Name','Defense']]
defense[defense['Defense']>200]
# Out:
#              Name  Defense
# 224  Mega Steelix      230
# 230       Shuckle      230
# 333   Mega Aggron      230

# %%
# TODO 10: Display the Pokemon who have Attack greater than 100 and Defense less than 150

att=df[['Name','Defense','Attack']]
att[(att['Defense']<150) & (att['Attack']>100)]
# Out:
#                  Name  Defense  Attack
# 7    Mega Charizard X      111     130
# 8    Mega Charizard Y       78     104
# 12     Mega Blastoise      120     103
# 19      Mega Beedrill       40     150
# 39           Nidoking       77     102
# ..                ...      ...     ...
# 793           Yveltal       95     131
# 796      Mega Diancie      110     160
# 797    Hoopa Confined       60     110
# 798     Hoopa Unbound       60     160
# 799         Volcanion      120     110
#
# [162 rows x 3 columns]

# %% [markdown]
# ### Cleaning data

# %%
from google.colab import files
files.upload()

# %%
data = pd.read_csv('pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# TODO 11: Drop all null values (Make sure that inplace is False)
data.dropna()
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 6      7       Charizard     Fire  Flying  78      84       78      109
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 6         85    100           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [414 rows x 12 columns]

# %% [markdown]
# **TODO 12:** Box plot </br>
# Have a boxplot of Attack grouped by their `Legendary` status </br>
# The expected output is as follows:
#
# ![download (2).png](data:image/png;base64,...)

# %%
# Run TODO 12 here
leg=data.groupby('Legendary')
data.boxplot(by='Legendary',column=['Attack'],figsize=(7,7))
# Out:
# C:\Users\nakoo\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# TODO 13: Sort data in the alphabetic order of the Pokemon's name (make sure that inplace=True)
data.sort_values(by='Name',inplace=True)
data.head()
# Out:
#        #                   Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 510  511              Abomasnow    Grass    Ice  90      92       75       92
# 68    69                   Abra  Psychic    NaN  25      20       15      105
# 392  393                  Absol     Dark    NaN  65     130       60       75
# 678  679               Accelgor      Bug    NaN  80      70       40      100
# 750  751  Aegislash Blade Forme    Steel  Ghost  60     150       50      150
#
#      Sp. Def  Speed  Generation  Legendary
# 510       85     60           4      False
# 68        55     90           1      False
# 392       60     75           3      False
# 678       60    145           5      False
# 750       50     60           6      False

# %% [markdown]
# ### Manipulating Dataframes with Pandas
#
# Import the file again as we intend to reset the data

# %%
from google.colab import files
files.upload()

# %%
data = pd.read_csv('pokemon.csv')

# %%
data = data.set_index('#')
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
# TODO 14: Find the HP of the 88th Pokemon

data[['Name','HP']].iloc[[87]]
# Out:
#             Name  HP
# #
# 88  Mega Slowbro  95

# %%
# TODO 15: Create a dataframe with just HP and attack and name it hp_attack

hp_attack=data[['Name','HP','Attack']]

# %%
# TODO 16: Print the first 10 Pokemon in descending order (# 10, 9, ..., 1)
data.sort_values(by='Name',ascending=False).head(10)
# Out:
#                    Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 795  Zygarde Half Forme    Dragon    Ground  108     100      121       81
# 696            Zweilous      Dark    Dragon   72      85       70       65
# 47                Zubat    Poison    Flying   40      45       35       30
# 632               Zorua      Dark       NaN   40      65       40       80
# 633             Zoroark      Dark       NaN   60     105       60      120
# 287           Zigzagoon    Normal       NaN   38      30       41       30
# 708              Zekrom    Dragon  Electric  100     150      120      120
# 583           Zebstrika  Electric       NaN   75     100       63       80
# 158              Zapdos  Electric    Flying   90      90       85      125
# 368            Zangoose    Normal       NaN   73     115       60       60
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 795       95     95           6       True
# 696       70     58           5      False
# 47        40     55           1      False
# 632       40     65           5      False
# 633       60    105           5      False
# 287       41     60           3      False
# 708      100     90           5       True
# 583       63    116           5      False
# 158       90    100           1       True
# 368       60     90           3      False

# %%
# TODO 17: Set index to 'Type 1' and 'Type 2' respectively and print the first 100 values
data.set_index(['Type 1','Type 2']).head(100)
# Out:
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Grass  Poison      Bulbasaur   45      49       49       65       65     45
#        Poison        Ivysaur   60      62       63       80       80     60
#        Poison       Venusaur   80      82       83      100      100     80
#        Poison  Mega Venusaur   80     100      123      122      120     80
# Fire   NaN        Charmander   39      52       43       60       50     65
# ...                      ...  ...     ...      ...      ...      ...    ...
# Poison NaN            Grimer   80      80       50       40       50     25
#        NaN               Muk  105     105       75       65      100     50
# Water  NaN          Shellder   30      65      100       45       25     40
#        Ice          Cloyster   50      95      180       85       45     70
# Ghost  Poison         Gastly   30      35       30      100       35     80
#
#                Generation  Legendary
# Type 1 Type 2
# Grass  Poison           1      False
#        Poison           1      False
#        Poison           1      False
#        Poison           1      False
# Fire   NaN              1      False
# ...                   ...        ...
# Poison NaN              1      False
#        NaN              1      False
# Water  NaN              1      False
#        Ice              1      False
# Ghost  Poison           1      False
#
# [100 rows x 9 columns]

# %%
# TODO 18: Plot 'Attack' vs. 'Defense' and pivot the data based on the 'Generation'

sns.lmplot(x='Attack',y='Defense',data=data, hue = 'Generation',fit_reg=False)
